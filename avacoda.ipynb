# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/USER/Desktop/avocado.csv')

# %%
df
# Out:
#        index        Date  AveragePrice  Total Volume  PLU 4046    PLU4225  \
# 0          0  12/27/2015          1.33      64236.62   1036.74   54454.85
# 1          1  12/20/2015          1.35      54876.98    674.28   44638.81
# 2          2  12/13/2015          0.93     118220.22    794.70  109149.67
# 3          3   12/6/2015          1.08      78992.15   1132.00   71976.41
# 4          4  11/29/2015          1.28      51039.60    941.48   43838.39
# ...      ...         ...           ...           ...       ...        ...
# 18244      7    2/4/2018          1.63      17074.83   2046.96    1529.20
# 18245      8   1/28/2018          1.71      13888.04   1191.70    3431.50
# 18246      9   1/21/2018          1.87      13766.76   1191.92    2452.79
# 18247     10   1/14/2018          1.93      16205.22   1527.63    2981.04
# 18248     11    1/7/2018          1.62      17489.58   2894.77    2356.13
#
#        PLU4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# ...

# %%
df.head(15)
# Out:
#     index        Date  AveragePrice  Total Volume  PLU 4046    PLU4225  \
# 0       0  12/27/2015          1.33      64236.62   1036.74   54454.85
# 1       1  12/20/2015          1.35      54876.98    674.28   44638.81
# 2       2  12/13/2015          0.93     118220.22    794.70  109149.67
# 3       3   12/6/2015          1.08      78992.15   1132.00   71976.41
# 4       4  11/29/2015          1.28      51039.60    941.48   43838.39
# 5       5  11/22/2015          1.26      55979.78   1184.27   48067.99
# 6       6  11/15/2015          0.99      83453.76   1368.92   73672.72
# 7       7   11/8/2015          0.98     109428.33    703.75  101815.36
# 8       8   11/1/2015          1.02      99811.42   1022.15   87315.57
# 9       9  10/25/2015          1.07      74338.76    842.40   64757.44
# 10     10  10/18/2015          1.12      84843.44    924.86   75595.85
# 11     11  10/11/2015          1.28      64489.17   1582.03   52677.92
# ...

# %%
df.tail(15)
# Out:
#        index       Date  AveragePrice  Total Volume  PLU 4046   PLU4225  \
# 18234      9  1/21/2018          1.83     189317.99  27049.44  33561.32
# 18235     10  1/14/2018          1.82     207999.67  33869.12  47435.14
# 18236     11   1/7/2018          1.48     297190.60  34734.97  62967.74
# 18237      0  3/25/2018          1.62      15303.40   2325.30   2171.66
# 18238      1  3/18/2018          1.56      15896.38   2055.35   1499.55
# 18239      2  3/11/2018          1.56      22128.42   2162.67   3194.25
# 18240      3   3/4/2018          1.54      17393.30   1832.24   1905.57
# 18241      4  2/25/2018          1.57      18421.24   1974.26   2482.65
# 18242      5  2/18/2018          1.56      17597.12   1892.05   1928.36
# 18243      6  2/11/2018          1.57      15986.17   1924.28   1368.32
# 18244      7   2/4/2018          1.63      17074.83   2046.96   1529.20
# 18245      8  1/28/2018          1.71      13888.04   1191.70   3431.50
# ...

# %%
#we can drop the index column which in not contributing in datasets
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#              Date  AveragePrice  Total Volume  PLU 4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33      64236.62   1036.74   54454.85    48.16
# 1      12/20/2015          1.35      54876.98    674.28   44638.81    58.33
# 2      12/13/2015          0.93     118220.22    794.70  109149.67   130.50
# 3       12/6/2015          1.08      78992.15   1132.00   71976.41    72.58
# 4      11/29/2015          1.28      51039.60    941.48   43838.39    75.78
# ...           ...           ...           ...       ...        ...      ...
# 18244    2/4/2018          1.63      17074.83   2046.96    1529.20     0.00
# 18245   1/28/2018          1.71      13888.04   1191.70    3431.50     0.00
# 18246   1/21/2018          1.87      13766.76   1191.92    2452.79   727.94
# 18247   1/14/2018          1.93      16205.22   1527.63    2981.04   727.01
# 18248    1/7/2018          1.62      17489.58   2894.77    2356.13   224.53
#
# ...

# %% [markdown]
# now datasets contain the total 18249 rows and 13 columns

# %%
df.shape
# Out:
# (18249, 13)

# %% [markdown]
# as we can see datasets comtain total 13 columns after deleting the index column

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# PLU 4046        float64
# PLU4225         float64
# PLU4770         float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   PLU 4046      18249 non-null  float64
#  4   PLU4225       18249 non-null  float64
#  5   PLU4770       18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# as we can see datasets contain float,int and object types dataset.most of data is float types

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'PLU 4046', 'PLU4225',
#        'PLU4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
#checking the nan value
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# PLU 4046        0
# PLU4225         0
# PLU4770         0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# as we can observe dataset does not contain any nan value

# %%
#checking the null value by visualisation
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume      PLU 4046       PLU4225       PLU4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# outlier present in some columns
#
# in total volume column,mean is greater than median means data is skewed to right side or positive skewness present in columns

# %% [markdown]
# # analysing the data with the help of visualisation

# %%
sns.barplot(x='year',y='AveragePrice',data=df)
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# from the graph it is showing in 2017 average price is maximum

# %%
sns.barplot(x='year',y='AveragePrice',data=df,hue='type')
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>

# %%
df.hist(figsize=(30,30),layout=(4,4),grid=True,bins=30)
# Out:
# array([[<Axes: title={'center': 'AveragePrice'}>,
#         <Axes: title={'center': 'Total Volume'}>,
#         <Axes: title={'center': 'PLU 4046'}>,
#         <Axes: title={'center': 'PLU4225'}>],
#        [<Axes: title={'center': 'PLU4770'}>,
#         <Axes: title={'center': 'Total Bags'}>,
#         <Axes: title={'center': 'Small Bags'}>,
#         <Axes: title={'center': 'Large Bags'}>],
#        [<Axes: title={'center': 'XLarge Bags'}>,
#         <Axes: title={'center': 'year'}>, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# The above histogram grph  shows thataverage price columns is distributed normally and skewness present in rest of columns

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# PLU 4046         8.648220
# PLU4225          8.942466
# PLU4770         10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
df['Total Volume']=np.log(df['Total Volume'])

# %%
df['PLU 4046']=np.cbrt(df['PLU 4046'])

# %%
df['PLU4225']=np.cbrt(df['PLU4225'])

# %%
df['PLU4770']=np.cbrt(df['PLU4770'])

# %%
df['Total Bags']=np.cbrt(df['Total Bags'])

# %%
df['Small Bags']=np.cbrt(df['Small Bags'])

# %%
df['Large Bags']=np.cbrt(df['Large Bags'])

# %%
df['XLarge Bags']=np.cbrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# index           0.108334
# AveragePrice    0.580303
# Total Volume    0.087954
# PLU 4046        2.277861
# PLU4225         2.130378
# PLU4770         2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# year            0.215339
# dtype: float64

# %%
#encoding the categorical columns into the numerical
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['type']=le.fit_transform(df['type'])

# %%
df['region']=le.fit_transform(df['region'])

# %%
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
# Out:
# AveragePrice       Axes(0.125,0.712609;0.133621x0.167391)
# Total Volume    Axes(0.285345,0.712609;0.133621x0.167391)
# PLU 4046         Axes(0.44569,0.712609;0.133621x0.167391)
# PLU4225         Axes(0.606034,0.712609;0.133621x0.167391)
# PLU4770         Axes(0.766379,0.712609;0.133621x0.167391)
# Total Bags         Axes(0.125,0.511739;0.133621x0.167391)
# Small Bags      Axes(0.285345,0.511739;0.133621x0.167391)
# Large Bags       Axes(0.44569,0.511739;0.133621x0.167391)
# XLarge Bags     Axes(0.606034,0.511739;0.133621x0.167391)
# type            Axes(0.766379,0.511739;0.133621x0.167391)
# year                Axes(0.125,0.31087;0.133621x0.167391)
# region           Axes(0.285345,0.31087;0.133621x0.167391)
# dtype: object

# %%
from scipy.stats import zscore

# %%
feature=df[['PLU 4046','PLU4225','PLU4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]
z=np.abs(zscore(feature))
z
# Out:
#        PLU 4046   PLU4225   PLU4770  Total Bags  Small Bags  Large Bags  \
# 0      0.230816  0.199902  0.212091    0.234170    0.232647    0.222352
# 1      0.231103  0.208054  0.211997    0.233350    0.231568    0.222335
# 2      0.231007  0.154478  0.211325    0.234730    0.233399    0.222311
# 3      0.230741  0.185350  0.211864    0.237096    0.236568    0.222186
# 4      0.230891  0.208719  0.211834    0.236718    0.236154    0.221924
# ...         ...       ...       ...         ...         ...         ...
# 18244  0.230017  0.243857  0.212540    0.229301    0.226665    0.220964
# 18245  0.230693  0.242277  0.212540    0.233594    0.232196    0.221403
# 18246  0.230693  0.243090  0.205766    0.233463    0.231644    0.222561
# 18247  0.230428  0.242651  0.205774    0.231866    0.229543    0.222529
# 18248  0.229347  0.243170  0.210450    0.230807    0.228111    0.222628
#
#        XLarge Bags
# 0          0.17558
# 1          0.17558
# 2          0.17558
# 3          0.17558
# ...

# %%
np.where(z>3)
# Out:
# (array([ 346,  359,  780, ..., 9111, 9112, 9113], dtype=int64),
#  array([0, 0, 6, ..., 5, 5, 5], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#              Date  AveragePrice  Total Volume  PLU 4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33      64236.62   1036.74   54454.85    48.16
# 1      12/20/2015          1.35      54876.98    674.28   44638.81    58.33
# 2      12/13/2015          0.93     118220.22    794.70  109149.67   130.50
# 3       12/6/2015          1.08      78992.15   1132.00   71976.41    72.58
# 4      11/29/2015          1.28      51039.60    941.48   43838.39    75.78
# ...           ...           ...           ...       ...        ...      ...
# 18244    2/4/2018          1.63      17074.83   2046.96    1529.20     0.00
# 18245   1/28/2018          1.71      13888.04   1191.70    3431.50     0.00
# 18246   1/21/2018          1.87      13766.76   1191.92    2452.79   727.94
# 18247   1/14/2018          1.93      16205.22   1527.63    2981.04   727.01
# 18248    1/7/2018          1.62      17489.58   2894.77    2356.13   224.53
#
# ...

# %%
print('old dataframe',df.shape[0])
print('new dataframe',df1.shape[0])
# Out:
# old dataframe 18249
# new dataframe 17782

# %%
df1.corr()
# Out:
#               AveragePrice  Total Volume  PLU 4046   PLU4225   PLU4770  \
# AveragePrice      1.000000     -0.328226 -0.327348 -0.243080 -0.240676
# Total Volume     -0.328226      1.000000  0.876417  0.871754  0.647854
# PLU 4046         -0.327348      0.876417  1.000000  0.565557  0.492545
# PLU4225          -0.243080      0.871754  0.565557  1.000000  0.620568
# PLU4770          -0.240676      0.647854  0.492545  0.620568  1.000000
# Total Bags       -0.295100      0.912311  0.728264  0.758097  0.558417
# Small Bags       -0.274138      0.905779  0.707104  0.779038  0.571925
# Large Bags       -0.267604      0.641029  0.561448  0.452271  0.324308
# XLarge Bags      -0.152351      0.514086  0.415807  0.392463  0.496278
# type              0.608447     -0.416905 -0.342523 -0.384443 -0.322876
# year              0.099910     -0.006465 -0.035792 -0.041588 -0.082975
# region            0.010428      0.074648  0.117225  0.009466 -0.096766
#
# ...

# %%
corr_hmap=df1.corr()
plt.figure(figsize=(20,25))
sns.heatmap(df1.corr(),annot=True,linewidths=0.1,fmt='.1g')
plt.show()

# %%
#seprating the feature and label column
x=df1.drop(columns=['AveragePrice','Date'])

# %%
y=df1.AveragePrice

# %%
x
# Out:
#        Total Volume  PLU 4046    PLU4225  PLU4770  Total Bags  Small Bags  \
# 0          64236.62   1036.74   54454.85    48.16     8696.87     8603.62
# 1          54876.98    674.28   44638.81    58.33     9505.56     9408.07
# 2         118220.22    794.70  109149.67   130.50     8145.35     8042.21
# 3          78992.15   1132.00   71976.41    72.58     5811.16     5677.40
# 4          51039.60    941.48   43838.39    75.78     6183.95     5986.26
# ...             ...       ...        ...      ...         ...         ...
# 18244      17074.83   2046.96    1529.20     0.00    13498.67    13066.82
# 18245      13888.04   1191.70    3431.50     0.00     9264.84     8940.04
# 18246      13766.76   1191.92    2452.79   727.94     9394.11     9351.80
# 18247      16205.22   1527.63    2981.04   727.01    10969.54    10919.54
# 18248      17489.58   2894.77    2356.13   224.53    12014.15    11988.14
#
#        Large Bags  XLarge Bags  type  year  region
# ...

# %%
y
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 17782, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#        Total Volume  PLU 4046   PLU4225   PLU4770  Total Bags  Small Bags  \
# 0         -0.389897 -0.348020 -0.276405 -0.320903   -0.427332   -0.399005
# 1         -0.399166 -0.348847 -0.301078 -0.320607   -0.424457   -0.395490
# 2         -0.336431 -0.348572 -0.138931 -0.318507   -0.429293   -0.401459
# 3         -0.375283 -0.347803 -0.232365 -0.320192   -0.437592   -0.411794
# 4         -0.402967 -0.348237 -0.303089 -0.320099   -0.436266   -0.410444
# ...             ...       ...       ...       ...         ...         ...
# 17777     -0.436606 -0.345714 -0.409433 -0.322304   -0.410260   -0.379500
# 17778     -0.439762 -0.347666 -0.404651 -0.322304   -0.425313   -0.397535
# 17779     -0.439882 -0.347666 -0.407111 -0.301126   -0.424853   -0.395736
# 17780     -0.437467 -0.346900 -0.405784 -0.301153   -0.419252   -0.388884
# 17781     -0.436195 -0.343779 -0.407354 -0.315772   -0.415538   -0.384214
#
#        Large Bags  XLarge Bags      type      year    region
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif=pd.DataFrame()
vif["VIF.values"] = [variance_inflation_factor(x.values, i) 
                          for i in range(len(x.columns))] 
vif['features']=x.columns
vif
# Out:
#       VIF.values      features
# 0   4.132391e+08  Total Volume
# 1   7.781043e+07      PLU 4046
# 2   6.415976e+07       PLU4225
# 3   4.789230e+05       PLU4770
# 4   1.928736e+13    Total Bags
# 5   1.275807e+13    Small Bags
# 6   1.291910e+12    Large Bags
# 7   6.649446e+09   XLarge Bags
# 8   1.233759e+00          type
# 9   1.090764e+00          year
# 10  1.062091e+00        region

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from  sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        acc=maxAccu
        maxRs=i
print('maximuu r2 score',maxAccu,'on random state',maxRs)
# Out:
# maximuu r2 score 0 on random state 199

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=43)

# %%
x_train.shape
# Out:
# (11913, 11)

# %%
x_test.shape
# Out:
# (5869, 11)

# %%
y_test.shape
# Out:
# (5869,)

# %%
y_train.shape
# Out:
# (11913,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print('R2 score:',r2_score(y_test,pred_lr))
print("r2 score on training data :",r2_score(y_train,pred_train))
print("mean absolute error:",mean_absolute_error(y_test,pred_lr))
print("mean squared error:",mean_squared_error(y_test,pred_lr))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2 score: 0.41080740680189387
# r2 score on training data : 0.4036126578183029
# mean absolute error: 0.23738186546406537
# mean squared error: 0.09470999589235328
# root mean squared error: 0.3077498917828458

# %%
r2 score on linearregression is 41

# %%
 from sklearn.linear_model import Ridge,Lasso

# %%
lasso=Lasso(alpha=.0001)
lasso.fit(x_train,y_train)
pred_lasso=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_lasso))
print('mean squared error:',mean_squared_error(y_test,pred_lasso))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.41080740680189387
# R2 score on training data: 0.4036126578183029
# mean absolute error: 0.23738186546406537
# mean squared error: 0.09470999589235328
# root mean squared error: 0.3077498917828458

# %%
ridge=Ridge(alpha=0.0001)
ridge.fit(x_train,y_train)
pred_ridge=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_ridge))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_ridge))
print('mean squared error:',mean_squared_error(y_test,pred_ridge))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2 score: 0.41080740680189387
# R2 score on training data: 0.4036126578183029
# mean absolute error: 0.23738186546406537
# mean squared error: 0.09470999589235328
# root mean squared error: 0.3077498917828458

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr_pred=gbr.predict(x_test)
gbr_train=gbr.predict(x_train)
print('R2 score:',r2_score(y_test,gbr_pred))
print('R2  score on training data:',r2_score(y_train,gbr_train))
print('mean absolute error:',mean_absolute_error(y_test,gbr_pred))
print('mean squared errro:',mean_squared_error(y_test,gbr_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,gbr_pred)))
# Out:
# R2 score: 0.6720667942262621
# R2  score on training data: 0.6974330065553465
# mean absolute error: 0.17117294561071617
# mean squared errro: 0.05271375256639393
# root mean squared error: 0.2295947572711405

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
etr_pred=etr.predict(x_test)
etr_train=etr.predict(x_train)
print('R2 score:',r2_score(y_test,etr_pred))
print('R2  score on training data:',r2_score(y_train,etr_train))
print('mean absolute error:',mean_absolute_error(y_test,etr_pred))
print('mean squared errro:',mean_squared_error(y_test,etr_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,etr_pred)))
# Out:
# R2 score: 0.8670044969142383
# R2  score on training data: 1.0
# mean absolute error: 0.10147508945305843
# mean squared errro: 0.021378414624297147
# root mean squared error: 0.14621359247449311

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(etr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [0.29474702 0.2596016  0.57680199 0.31418269 0.11623699]
# 0.31231405730321216
# difference between R2 score and cross validation score: 9.849334949868172

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [-1.03104406e-01  6.59983718e-02  2.95360746e-01 -5.32448931e-02
#  -1.13995412e+02]
# -22.75808042904356
# difference between R2 score and cross validation score: 2316.8887835845453

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(gbr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [0.28325245 0.37594866 0.56641091 0.35454681 0.10758281]
# 0.33754832991529293
# difference between R2 score and cross validation score: 7.325907688660093

# %% [markdown]
# # prediction of region

# %%
x_a=df1.drop(columns=['region','Date'])

# %%
y_b=df1.region

# %%
x_a
# Out:
#        AveragePrice  Total Volume  PLU 4046    PLU4225  PLU4770  Total Bags  \
# 0              1.33      64236.62   1036.74   54454.85    48.16     8696.87
# 1              1.35      54876.98    674.28   44638.81    58.33     9505.56
# 2              0.93     118220.22    794.70  109149.67   130.50     8145.35
# 3              1.08      78992.15   1132.00   71976.41    72.58     5811.16
# 4              1.28      51039.60    941.48   43838.39    75.78     6183.95
# ...             ...           ...       ...        ...      ...         ...
# 18244          1.63      17074.83   2046.96    1529.20     0.00    13498.67
# 18245          1.71      13888.04   1191.70    3431.50     0.00     9264.84
# 18246          1.87      13766.76   1191.92    2452.79   727.94     9394.11
# 18247          1.93      16205.22   1527.63    2981.04   727.01    10969.54
# 18248          1.62      17489.58   2894.77    2356.13   224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year
# ...

# %%
y_b
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 17782, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_a=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x_a
# Out:
#        Total Volume  PLU 4046   PLU4225   PLU4770  Total Bags  Small Bags  \
# 0         -0.389897 -0.348020 -0.276405 -0.320903   -0.427332   -0.399005
# 1         -0.399166 -0.348847 -0.301078 -0.320607   -0.424457   -0.395490
# 2         -0.336431 -0.348572 -0.138931 -0.318507   -0.429293   -0.401459
# 3         -0.375283 -0.347803 -0.232365 -0.320192   -0.437592   -0.411794
# 4         -0.402967 -0.348237 -0.303089 -0.320099   -0.436266   -0.410444
# ...             ...       ...       ...       ...         ...         ...
# 17777     -0.436606 -0.345714 -0.409433 -0.322304   -0.410260   -0.379500
# 17778     -0.439762 -0.347666 -0.404651 -0.322304   -0.425313   -0.397535
# 17779     -0.439882 -0.347666 -0.407111 -0.301126   -0.424853   -0.395736
# 17780     -0.437467 -0.346900 -0.405784 -0.301153   -0.419252   -0.388884
# 17781     -0.436195 -0.343779 -0.407354 -0.315772   -0.415538   -0.384214
#
#        Large Bags  XLarge Bags      type      year    region
# ...

# %%
train_xa,test_xa,train_yb,test_yb=train_test_split(x_a,y_b,test_size=0.33,random_state=50)

# %%
train_xa.shape
# Out:
# (11913, 11)

# %%
test_xa.shape
# Out:
# (5869, 11)

# %%
train_yb.shape
# Out:
# (11913,)

# %%
test_yb.shape
# Out:
# (5869,)

# %%
lg=LogisticRegression()
lg.fit(train_xa,train_yb)
predlg=lg.predict(test_xa)
print(accuracy_score(test_yb,predlg))
print(confusion_matrix(test_yb,predlg))
print(classification_report(test_yb,predlg))
# Out:
# 0.6798432441642529
# [[95  0  0 ...  0  0  0]
#  [53 61  0 ...  0  0  0]
#  [22 19 62 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 44 12  0]
#  [ 0  0  0 ...  1 71  2]
#  [ 0  0  0 ...  0  0 96]]
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72        95
#            1       0.61      0.54      0.57       114
#            2       0.82      0.60      0.69       103
#            3       0.79      0.79      0.79       115
#            4       0.75      0.56      0.64       105
#            5       0.63      0.73      0.68        99
#            6       0.99      0.99      0.99        86
#            7       0.62      0.92      0.74       104
#            8       0.92      0.67      0.78       121
#            9       0.90      0.78      0.84       111
#           10       0.76      0.75      0.75       119
#           11       0.77      0.79      0.78       116
#           12       0.80      0.72      0.76       116
# ...

# %%
knn=KNeighborsClassifier()
knn.fit(train_xa,train_yb)
predknn=knn.predict(test_xa)
print(accuracy_score(test_yb,predknn))
print(confusion_matrix(test_yb,predknn))
print(classification_report(test_yb,predknn))
# Out:
# 0.9773385585278582
# [[ 95   0   0 ...   0   0   0]
#  [  0 114   0 ...   0   0   0]
#  [  0   0 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  56   0   0]
#  [  0   0   0 ...   0  75   0]
#  [  0   0   0 ...   0   0  95]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00       114
#            2       0.97      1.00      0.99       103
#            3       1.00      1.00      1.00       115
#            4       1.00      0.96      0.98       105
#            5       1.00      0.99      0.99        99
#            6       0.99      0.99      0.99        86
#            7       0.97      0.99      0.98       104
#            8       0.98      0.99      0.99       121
#            9       0.97      0.94      0.95       111
#           10       0.96      0.98      0.97       119
#           11       0.97      0.95      0.96       116
# ...

# %%
rf=RandomForestClassifier()
rf.fit(train_xa,train_yb)
predrf=rf.predict(test_xa)
print(accuracy_score(test_yb,predrf))
print(confusion_matrix(test_yb,predrf))
print(classification_report(test_yb,predrf))
# Out:
# 0.9955699437723633
# [[ 95   0   0 ...   0   0   0]
#  [  0 114   0 ...   0   0   0]
#  [  0   0 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  56   0   0]
#  [  0   0   0 ...   0  75   0]
#  [  0   0   0 ...   0   0  96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00       114
#            2       1.00      1.00      1.00       103
#            3       1.00      1.00      1.00       115
#            4       1.00      1.00      1.00       105
#            5       1.00      1.00      1.00        99
#            6       0.99      1.00      0.99        86
#            7       1.00      1.00      1.00       104
#            8       1.00      1.00      1.00       121
#            9       1.00      1.00      1.00       111
#           10       1.00      1.00      1.00       119
#           11       1.00      0.99      1.00       116
# ...

# %%
sv=SVC()
sv.fit(train_xa,train_yb)
predsv=sv.predict(test_xa)
print(accuracy_score(test_yb,predsv))
print(confusion_matrix(test_yb,predsv))
print(classification_report(test_yb,predsv))
# Out:
# 0.6130516271937297
# [[95  0  0 ...  0  0  0]
#  [62 52  0 ...  0  0  0]
#  [ 0  0 43 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 56  0  0]
#  [ 0  0  0 ...  0 73  1]
#  [ 0  0  0 ...  0  0 96]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        95
#            1       1.00      0.46      0.63       114
#            2       0.88      0.42      0.57       103
#            3       0.98      0.43      0.60       115
#            4       0.43      0.91      0.58       105
#            5       0.96      0.45      0.62        99
#            6       0.99      0.95      0.97        86
#            7       0.38      1.00      0.55       104
#            8       0.95      0.48      0.64       121
#            9       1.00      0.37      0.54       111
#           10       0.95      0.49      0.64       119
#           11       0.43      0.98      0.60       116
#           12       0.95      0.54      0.69       116
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()
ad.fit(train_xa,train_yb)
predad=rf.predict(test_xa)
print(accuracy_score(test_yb,predad))
print(confusion_matrix(test_yb,predad))
print(classification_report(test_yb,predad))
# Out:
# 0.9955699437723633
# [[ 95   0   0 ...   0   0   0]
#  [  0 114   0 ...   0   0   0]
#  [  0   0 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  56   0   0]
#  [  0   0   0 ...   0  75   0]
#  [  0   0   0 ...   0   0  96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00       114
#            2       1.00      1.00      1.00       103
#            3       1.00      1.00      1.00       115
#            4       1.00      1.00      1.00       105
#            5       1.00      1.00      1.00        99
#            6       0.99      1.00      0.99        86
#            7       1.00      1.00      1.00       104
#            8       1.00      1.00      1.00       121
#            9       1.00      1.00      1.00       111
#           10       1.00      1.00      1.00       119
#           11       1.00      0.99      1.00       116
# ...

# %%
from sklearn.ensemble import ExtraTreesRegressor
ent=ExtraTreesRegressor()
ent.fit(train_xa,train_yb)
predent=ent.predict(test_xa)
print(accuracy_score(test_yb,predent))
print(confusion_matrix(test_yb,predent))
print(classification_report(test_yb,predent))
# Out:
# 1.0
# [[ 95   0   0 ...   0   0   0]
#  [  0 114   0 ...   0   0   0]
#  [  0   0 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  56   0   0]
#  [  0   0   0 ...   0  75   0]
#  [  0   0   0 ...   0   0  96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00       114
#            2       1.00      1.00      1.00       103
#            3       1.00      1.00      1.00       115
#            4       1.00      1.00      1.00       105
#            5       1.00      1.00      1.00        99
#            6       1.00      1.00      1.00        86
#            7       1.00      1.00      1.00       104
#            8       1.00      1.00      1.00       121
#            9       1.00      1.00      1.00       111
#           10       1.00      1.00      1.00       119
#           11       1.00      1.00      1.00       116
#           12       1.00      1.00      1.00       116
# ...

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(rf,x_a,y_b)
print(score)
print(score.mean())
print('difference between accuracy and cross validation score is',accuracy_score(test_yb,predrf)-score.mean())
# Out:
# [0.95276919 0.99156593 0.98143982 0.97975253 0.89173228]
# 0.9594519496561384
# difference between accuracy and cross validation score is 0.03611799411622485

# %%
score=cross_val_score(knn,x_a,y_b)
print(score)
print(score.mean())
print('difference between accuracy and cross validation score is',accuracy_score(test_yb,predknn)-score.mean())
# Out:
# [0.74754006 0.75428732 0.90494938 0.62992126 0.11839145]
# 0.6310178949728557
# difference between accuracy and cross validation score is 0.3463206635550026

# %%
score=cross_val_score(lg,x_a,y_b)
print(score)
print(score.mean())
print('difference between accuracy and cross validation score is',accuracy_score(test_yb,predlg)-score.mean())
# Out:
# [0.74500984 0.81360697 0.62823397 0.49971879 0.34139483]
# 0.6055928786944927
# difference between accuracy and cross validation score is 0.07425036546976016

# %%
score=cross_val_score(ad,x_a,y_b)
print(score)
print(score.mean())
print('difference between accuracy and cross validation score is',accuracy_score(test_yb,predad)-score.mean())
# Out:
# [0.07562553 0.07562553 0.09026997 0.05652418 0.05652418]
# 0.07091387789346124
# difference between accuracy and cross validation score is 0.924656065878902

# %%
score=cross_val_score(ent,x_a,y_b)
print(score)
print(score.mean())
print('difference between accuracy and cross validation score is',accuracy_score(test_yb,predent)-score.mean())
# Out:
# [1.         1.         1.         0.99999991 1.        ]
# 0.9999999819821307
# difference between accuracy and cross validation score is 1.8017869307662693e-08

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators=[20,60,100,120]
max_feature=['auto', 'sqrt']
max_depth=[2,8,None]
max_sample=[0.5,0.75,1.0]
bootstrap=['True','False']
min_samples_leaf=[1,2]
max_leaf_nodes=[None]

# %%
param_grid={'n_estimators':n_estimators,
           'max_feature':max_feature,
           'max_depth':max_depth,
           'max_sample':max_sample,
           'bootstrap':bootstrap,
            'min_samples_leaf':min_samples_leaf,
            'max_leaf_nodes':max_leaf_nodes
           }

# %%
print(param_grid)
# Out:
# {'n_estimators': [20, 60, 100, 120], 'max_feature': ['auto', 'sqrt'], 'max_depth': [2, 8, None], 'max_sample': [0.5, 0.75, 1.0], 'bootstrap': ['True', 'False'], 'min_samples_leaf': [1, 2], 'max_leaf_nodes': [None]}

# %%
rf_grid=GridSearchCV(estimator=rf,
                    param_grid=param_grid,cv=5,
                    verbose=2,
                    n_jobs=-1)

# %%
rf_grid.fit(train_xa,train_yb)
rf_grid.best_params_
rf_grid.best_score_
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py", line 428, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
# ...

# %%
#saving the model 
import joblib
joblib.dump(rf,'rffile.obj')
# Out:
# ['rffile.obj']

# %%
#loading the model from file
mymodel=joblib.load('rffile.obj')
mymodel.predict(test_xa)
# Out:
# array([13, 50,  0, ...,  5, 40, 46], dtype=int64)

# %%
mymodel
# Out:
# RandomForestClassifier()
